# %%
from src import visualization
graph1 = visualization.make_graph_tricks()
# Out:
# /Users/milastern/Documents/GitHub/Penney/src/visualization.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   win_matrix = df_pivot.applymap(lambda x: x[0] if isinstance(x, list) else 0).to_numpy()
# /Users/milastern/Documents/GitHub/Penney/src/visualization.py:22: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   draw_matrix = df_pivot.applymap(lambda x: x[2] if isinstance(x, list) else 0).to_numpy()

# %%
graph2 = visualization.make_graph_cards()
# Out:
# /Users/milastern/Documents/GitHub/Penney/src/visualization.py:50: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   win_matrix = df_pivot.applymap(lambda x: x[0] if isinstance(x, list) else 0).to_numpy()
# /Users/milastern/Documents/GitHub/Penney/src/visualization.py:51: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   draw_matrix = df_pivot.applymap(lambda x: x[2] if isinstance(x, list) else 0).to_numpy()
